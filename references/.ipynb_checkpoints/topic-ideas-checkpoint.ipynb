# %% [markdown]
# # Topic ideas
#
# ---
#
# Group name: mn086
#
# ---

# %% [markdown]
# ## Zusammenhang zwischen Fahrzeugbestand und sozioökonomischen Faktoren
#
# ### Datenquellen
#
# **1. Statistik des Kraftfahrzeug- und Anhängerbestandes**
#  - Quelle: [Statistisches Bundesamt](https://www-genesis.destatis.de/genesis/online/data), Code: 46251-0021
#  - Erläuterungen:
#
#       Statistik des Kraftfahrzeug- und Anhängerbestandes
#       (EVAS-Nr. 46251)
#
#       Vom Kraftfahrt-Bundesamt werden aus Meldungen der
#       Kraftfahrzeug-Zulassungsstellen Statistiken über den Bestand
#       an Kraftfahrzeugen und Anhängern (jährlich), Neuzulassungen
#       (monatlich), Besitzumschreibungen (monatlich) und Löschungen
#       (jährlich) durchgeführt.
#
#       Die statistischen Auswertungen umfassen alle nach der
#       Straßenverkehrs-Zulassungs-Ordnung (StVZO) in Deutschland
#       zugelassenen bzw. angemeldeten Fahrzeuge, denen ein
#       amtliches Kennzeichen zugeteilt wurde. Mit einbezogen sind
#       Fahrzeuge, die vorübergehend stillgelegt wurden sowie
#       Fahrzeuge des Bundesgrenzschutzes (BGS) und des Technischen
#       Hilfswerkes (THW). Dagegen sind nicht einbezogen die
#       Fahrzeuge der Bundeswehr sowie Fahrzeuge mit rotem
#       Kennzeichen und mit Ausfuhrkennzeichen.
#
#       Dem Kraftfahrtbundesamt (KBA) obliegt die statistische
#       Bearbeitung der Datenmeldungen der Zulassungsbehörden und
#       der Haftpflichtversicherungen (Kfz mit Versicherungs-
#       kennzeichen) sowie des Zentralen Fahrzeugregisters (ZFZR).
#       Es handelt sich dabei um Sekundärstatistiken, denen die
#       gemeldeten Kraftfahrzeuge und Kraftfahrzeuganhänger mit
#       deren Halterangaben zugrunde liegen.
#
#       © Statistisches Bundesamt, Wiesbaden 2010
#  - Stichtage: 01.01.2020 / 2021 / 2022 / 2023 /2024
#  - Datenbeschreibung:
#     - Landkreise (476 Merkmalsausprägungen): Dies dient als geografische Dimension.
#     - Kraftstoffarten (8 Merkmalsausprägungen je Landkreis): Klassifizierung, z.B. nach Benzin, Diesel, Elektro usw.
#     - Emissionsgruppen (10 Merkmalsausprägungen je Kraftstoffart): Klassifizierung der Fahrzeuge nach Emissionsnormen.
#     - Anzahl der Fahrzeuge: Dies ist eine quantitative Variable und könnte als Zielvariable (response variable) für eine Regressionsanalyse dienen.
#
# **2. Bevölkerung am Hauptwohnort nach Altersgruppen und Geschlecht**
#  - Quelle: [Regionalstatistik](https://www.regionalstatistik.de/genesis/online/), Code: 12211-Z-03
#  - Erläuterungen:
#
#      Begriffsinhalt:
#      Bevölkerung
#
#      Für die Darstellung von Ergebnissen des Mikrozensus auf
#      Individualebene - ohne Bezug zum Haushalts- und
#      Lebensformkontext - wird die "Bevölkerung am Ort
#      der alleinigen bzw. Hauptwohnung" zu Grunde gelegt.
#
#      Zur "Bevölkerung" gehören nach diesem Bevölkerungsbegriff
#      alle Personen mit nur einer Wohnung sowie Personen mit
#      mehreren Wohnungen am Ort ihrer Hauptwohnung. Dies ist die
#      vorwiegend genutzte Wohnung einer Person. Aus
#      melderechtlichen Gründen werden Soldatinnen und Soldaten im
#      Grundwehrdienst oder auf Wehrübung der Wohngemeinde vor
#      ihrer Einberufung zugeordnet. Entsprechend wird bei
#      Patientinnen und Patienten in Krankenhäusern sowie bei
#      Personen in Untersuchungshaft verfahren. Berufssoldatinnen
#      und Berufssoldaten, Soldatinnen und Soldaten auf Zeit,
#      Angehörige des Bundesgrenzschutzes und der
#      Bereitschaftspolizei in Gemeinschaftsunterkünften werden
#      ebenso wie die Strafgefangenen sowie alle Dauerinsassen von
#      Gemeinschaftsunterkünften und das in diesen Unterkünften
#      wohnende Personal sowohl in den Gemeinden, die diese
#      Unterkünfte beherbergen, als auch in den Gemeinden, in
#      denen sie evtl. einen weiteren Wohnsitz haben, erfasst.
#      Angehörige der ausländischen Stationierungsstreitkräfte
#      sowie der ausländischen diplomatischen und konsularischen
#      Vertretungen mit ihren Familienangehörigen werden
#      grundsätzlich nicht statistisch ermittelt.
#  - Verfügbarer Zeitraum: 2011 - 2019
#  - Datenbeschreibung:
#     - Landkreise (489 Merkmalsausprägungen; Aggregate: Bundesländer, Deutschland): Dies dient als geografische Dimension.
#     - Altersgruppen (4 Merkmalsausprägungen je Landkreis): Könnte als Prädiktor für die Fahrzeugwahl dienen.
#     - Geschlecht (2 Merkmalsausprägungen je Altersgruppe): Weitere Differenzierungsmöglichkeit.
#     - Anzahl der Personen (je Geschlecht, Altersgruppe, Landkreis): Diese könnte als zusätzliche Einflussgröße für die Anzahl der zugelassenen Fahrzeuge genutzt werden.
#
# **3. Verfügbares Einkommen je Einwohner**
#  - Quelle: [Regionalstatistik](https://www.regionalstatistik.de/genesis/online/), Code: AI-S-01
#  - Erläuterungen:
#
#     Verfügbares Einkommen der privaten Haushalte einschließlich privater Organisationen ohne Erwerbszweck je Einwohnerin bzw. Einwohner in EUR
#
#
#     Aussage
#     Der Indikator gibt Auskunft über den (monetären) Wohlstand der Bevölkerung und ist als der durchschnittliche Betrag zu verstehen, der je Einwohnerin bzw. Einwohner für Konsum- und Sparzwecke zur Verfügung steht.
#
#
#     Indikatorberechnung
#     Für die Berechnung des Indikators „Verfügbares Einkommen der privaten Haushalte einschließlich privater Organisationen ohne Erwerbszweck je Einwohnerin bzw. Einwohner in EUR“ wird der Wert des Verfügbaren Einkommens in jeweiligen Preisen im Jahr durch die Zahl der Einwohnerinnen und Einwohner im Jahresdurchschnitt dividiert. Für die Berechnung des Indikators 'Verfügbares Einkommen der privaten Haushalte einschließlich privater Organisationen ohne Erwerbszweck je Einwohnerin bzw. Einwohner in EUR' wird die jahresdurchschnittliche Zahl der Einwohnerinnen und Einwohner auf Basis des Zensus 2011 herangezogen. Die durchschnittliche Jahresbevölkerung ist das arithmetische Mittel aus Jahresanfangs- und Jahresendbestand.
#     Bei diesen Ergebnissen handelt es sich um Ergebnisse der Revision 2014 der Volkswirtschaftlichen Gesamtrechnungen der Länder. Die VGR-Generalrevision 2014 dient in erster Linie der europaweiten Einführung des neuen Europäischen Systems Volkswirtschaftlicher Gesamtrechnungen (ESVG 2010), welches eine Vielzahl von konzeptionellen Änderungen mit sich bringt. Darüber hinaus wurden sämtliche bisherigen Berechnungen und Ergebnisse überprüft sowie neue Erkenntnisse, methodische Verbesserungen und, soweit möglich, neue Datenquellen in das Rechenwerk integriert.
#
#
#     Herkunftsstatistik
#     Der Indikator beruht auf Daten des Arbeitskreises "Volkswirtschaftliche Gesamtrechnungen der Länder". Die Ergebnisse beziehen sich immer auf den zum jeweiligen Veröffentlichungstermin maßgeblichen Berechnungsstand.
#
#
#     Merkmalsbeschreibungen
#      - Verfügbares Einkommen der privaten Haushalte:
#     Das Verfügbare Einkommen ist als der Betrag zu verstehen, der den privaten Haushalten für Konsumzwecke oder zur Ersparnisbildung zur Verfügung steht. Es ergibt sich dadurch, dass dem Primäreinkommen die monetären Sozialleistungen (Rente, Arbeitslosenhilfe, Kindergeld etc.) sowie die sonstigen laufenden Transfers hinzugefügt werden und die Sozialbeiträge und die sonstigen laufenden Transfers sowie Einkommensteuern und andere Steuern, die von den privaten Haushalten zu leisten sind, abgezogen werden. Das Primäreinkommen der privaten Haushalte enthält die Einkommen aus Erwerbstätigkeit und Vermögen, die den inländischen privaten Haushalten zugeflossen sind (z. B. Selbstständigen- einkommen, Arbeitnehmerentgelt).
#      - Private Haushalte einschließlich privater Organisationen ohne Erwerbszweck:
#     Die privaten Haushalte treten in erster Linie als Anbieter von Arbeitskraft, als letzte Käufer von Ver- und Gebrauchsgütern und als Anleger von Ersparnissen auf. Ihre Einnahmen sind aber nicht allein vom Markt abhängig, denn neben Einkommen aus Erwerbstätigkeit und Vermögen spielen auch Einnahmen aus Übertragungen (Renten, Pensionen, Unterstützungen usw.) eine Rolle. In den regionalen Volkswirtschaftlichen Gesamtrechnungen müssen die privaten Haushalte aus methodischen Gründen mit den privaten Organisationen ohne Erwerbszweck zusammengefasst dargestellt werden. Bei den privaten Organisationen ohne Erwerbszweck handelt es sich um Organisationen, Verbände, Vereine, Institute usw., die nicht zum staatlichen Sektor gehören, ihre Leistungen aber ebenfalls unentgeltlich oder zu nicht voll die Kosten deckenden Preisen abgeben. Sie bestreiten ihre Aufwendungen - abgesehen von speziellen Entgelten - zu einem wesentlichen Teil aus Beiträgen und Zuwendungen privater Haushalte.
#      - Bevölkerung:
#     Die Bevölkerung einer Gemeinde umfasst seit Anfang der 1980er Jahre alle Personen, die auf der Grundlage der geltenden melderechtlichen Bestimmungen in dieser Gemeinde ihre alleinige oder die Hauptwohnung haben. Vorher wurde die Bevölkerung am Ort der alleinigen oder der vorwiegend benutzten Wohnung erfasst (Wohnbevölkerung). Bei den Bevölkerungsdaten handelt es sich um Fortschreibungszahlen, die ab dem Berichtsjahr 2011 auf den Ergebnissen des Zensus vom 09. Mai 2011 basieren. Die jährliche Fortschreibung der Bevölkerung erfolgt mit Hilfe der Ergebnisse der Statistik der natürlichen Bevölkerungsbewegung (Geburten, Sterbefälle und Eheschließungen), der Wanderungsstatistik (Zu- und Fortzüge) sowie von Daten zu Ehelösungen, Aufhebungen von Lebenspartnerschaften, dem Wechsel der Staatsangehörigkeit und Bestandskorrekturen aufgrund von nachgereichten Meldungen der Standes- und Einwohnermeldeämter. Zur Bevölkerung zählen auch die im Bundesgebiet gemeldeten Ausländer (einschließlich Staatenlose und Schutzsuchende). Nicht zur Bevölkerung gehören hingegen die Mitglieder der Stationierungsstreitkräfte sowie der ausländischen diplomatischen und konsularischen Vertretungen mit ihren Familienangehörigen. Die Ergebnisse können Fälle mit unbestimmtem oder diversem Geschlecht beinhalten, die durch ein definiertes Umschlüsselungsverfahren auf männlich und weiblich verteilt wurden.
#
#
#     Regionale Besonderheiten
#      - Alle Länder:
#     Bei den Bevölkerungsdaten handelt es sich um Fortschreibungszahlen, die ab dem Berichtsjahr 2011 auf den Ergebnissen des Zensus vom 09. Mai 2011 basieren. Bevölkerungsdaten für die Berichtsjahre 1987 bis 2010 wurden in den alten Bundesländern aufgrund der Ergebnisse der Volkszählung vom 25. Mai 1987 erstellt, in den neuen Bundesländern bildet die am 3. Oktober 1990 aufgrund eines Auszugs des zentralen Einwohnerregisters der ehemaligen DDR festgestellte amtliche Einwohnerzahl die Grundlage. Da vom Arbeitskreis Erwerbstätigenrechnung des Bundes und der Länder die Daten regelmäßig gebietsbereinigt veröffentlicht werden, können infolge der Bildung der Region Hannover (2001), der Städteregion Aachen (2009), des neuen Landkreises Göttingen (2016) sowie der Gebietsreformen in Sachsen-Anhalt (2007), Sachsen (2008) und Mecklenburg-Vorpommern (2011) für die Kreisebene für die jeweils vor dem genannten Zeitpunkt liegenden Berichtsjahre keine Werte angezeigt werden.
#  - Verfügbarer Zeitraum: 2000 - 2021
#  - Datenbeschreibung:
#     - Landkreise (489 Merkmalsausprägungen; Aggregate: Bundesländer, Deutschland): Dies dient als geografische Dimension.
#     - Einkommen (je Einwohner, Landkreis): Ein potenzieller Prädiktor für die Fahrzeugwahl (z.B. Elektrofahrzeuge in wohlhabenderen Regionen).
#
#
# **4. Straßenverkehrsunfälle bezogen auf Kfz**
#  - Quelle: [Regionalstatistik](https://www.regionalstatistik.de/genesis/online/), Code: AI013-3
#  - Erläuterungen:
#
#     Verfügbares Einkommen der privaten Haushalte einschließlich privater Organisationen ohne Erwerbszweck je Einwohnerin bzw. Einwohner in EUR
#
#
#     Aussage
#     Der Indikator ist ein Maßstab für die Unfallhäufigkeit im Straßenverkehr. Die Kennziffer hat jedoch den Nachteil, dass nur die am Ort gemeldeten Kfz berücksichtigt werden und ein starker Durchgangsverkehr oder ein hohes Pendleraufkommen das Ergebnis verfälschen. Dem Umfang des Verkehrsaufkommens wird also nicht genügend Rechnung getragen.
#
#
#     Indikatorberechnung
#     Für die Berechnung des Indikators 'Straßenverkehrsunfälle je 10.000 Kfz' wird die Zahl der Straßenverkehrsunfälle im Jahr durch die Zahl der Kraftfahrzeuge am 01.01. des Jahres dividiert und mit 10.000 multipliziert.
#
#
#     Herkunftsstatistik
#     Der Indikator beruht auf Daten aus der Statistik der Straßenverkehrsunfälle sowie auf Daten der amtlichen Kraftfahrzeugstatistik des Kraftfahrt-Bundesamtes zum Kraftfahrzeugbestand.
#
#
#     Merkmalsbeschreibungen
#      - Straßenverkehrsunfälle:
#     Nachgewiesen werden ab dem Berichtsjahr 1995 die von der Polizei erfassten Unfälle, bei denen infolge des Fahrverkehrs auf öffentlichen Wegen und Plätzen Personen getötet oder verletzt wurden bzw. Sachschaden entstanden ist. Zu den Unfällen mit Sachschaden zählen schwerwiegende Unfälle mit Sachschaden im engeren Sinne, bei denen ein Straftatbestand oder eine Ordnungswidrigkeit (Bußgeld) vorlag und gleichzeitig mindestens ein Kfz auf Grund eines Unfallschadens von der Unfallstelle abgeschleppt werden musste, sowie sonstige Sachschadensunfälle unter dem Einfluss berauschender Mittel (mindestens ein Unfallbeteiligter stand unter dem Einfluss berauschender Mittel und, falls Kfz beteiligt waren, waren diese alle noch fahrbereit). Nicht enthalten sind alle übrigen Sachschadensunfälle ohne den Einfluss berauschender Mittel. Ab dem 1. Januar 1995 wurden für die Erfassung der Unfälle mit Sachschaden im Sinne des Straßenverkehrsunfallstatistikgesetzes neue Kriterien festgelegt. Im Gegensatz zu früheren Berichtsjahren dient als Erfassungsgrundlage nicht mehr die Höhe des entstandenen Sachschadens, sondern die Feststellung, ob es sich um einen Straftatbestand/eine Ordnungswidrigkeit handelt und/oder mindestens ein Unfallbeteiligter unter Alkoholeinwirkung/ab 1. Januar 2008 unter dem Einfluss berauschender Mittel stand. Ebenfalls in die Beurteilung des Unfalls einbezogen wird die Fahrbereitschaft der Fahrzeuge. Aus diesem Grund ist ein Vergleich zu den Vorjahren nicht möglich.
#      - Kraftfahrzeugbestand:
#     Zahl der Fahrzeuge, die zum Zeitpunkt der Zählung an einem festgelegten Stichtag (1. Januar eines jeden Jahres) mit einem amtlichen Kennzeichen zum Verkehr zugelassen (bis 1.1.2007 einschließlich der vorübergehend abgemeldeten Fahrzeuge) und im Zentralen Fahrzeugregister (ZFZR) des Kraftfahrt-Bundesamtes (KBA) gespeichert sind. Mit einbezogen sind Fahrzeuge der Bundespolizei und des Technischen Hilfswerkes (THW). Dagegen sind nicht einbezogen die Fahrzeuge der Bundeswehr sowie Fahrzeuge mit rotem bzw. Kurzzeitkennzeichen und mit Ausfuhrkennzeichen. Die Daten zum Kraftfahrzeugbestand stammen vom Kraftfahrt-Bundesamt in Flensburg.
#
#
#     Regionale Besonderheiten
#      - Deutschland (bis 1999):
#     Einschl. Fahrzeuge mit BP-Kennzeichen, die nicht mehr gesondert ausgewiesen sind.
#      - Niedersachsen, Nordrhein-Westfalen, Rheinland-Pfalz, Bayern, Brandenburg, Sachsen und Sachsen-Anhalt (2006):
#     Landessumme einschl. Fahrzeuge, die regional nicht zugeordnet werden konnten.
#  - Verfügbarer Zeitraum: 1995 - 2023
#  - Datenbeschreibung:
#     - Landkreise (489 Merkmalsausprägungen; Aggregate: Bundesländer, Deutschland): Dies dient als geografische Dimension.
#     - Straßenverkehrsunfälle (je 10.000 Kfz, Landkreis)
#
#
# ### Forschungsfragen
#
#  - Wie beeinflussen sozioökonomische Faktoren die Anzahl der zugelassenen Fahrzeuge in einem Landkreis?
#    - Antwortwert: Anzahl der zugelassenen Fahrzeuge (pro Einwohner)
#    - Merkmalswerte: Einkommen, Einwohneranzahl, Altersstruktur, Geschlechterverteilung
# - Inwiefern beeinflussen demografische und wirtschaftliche Faktoren die Kraftstoffart & Emissionsgruppen von Fahrzeugen in verschiedenen Landkreisen?
#    - Antwortwert: Anteil von Fahrzeugen mit bestimmten Kraftstoff & Emissionsgruppen
#    - Merkmalswerte: Einkommen, Altersstruktur, Geschlechterverteilung
# - Welche Faktoren tragen zur Häufigkeit von Straßenverkehrsunfällen in Landkreisen bei?
#    - Antwortwert: Anzahl der Verkehrsunfälle
#    - Merkmalswerte: Anzahl der Fahrzeuge, Einkommen, Einwohneranzahl, Altersstruktur, Geschlechterverteilung
#
# ### Überblick über die Daten

# %%
import os
import pandas as pd

# %%
# Input
root_raw = os.path.join('..', 'data', 'raw')
data_veh = '46251-0021_de_2020_flat.csv'
data_pop = '12211-Z-03_flat.csv'
data_income = 'AI-S-01_flat.csv'
data_crash = 'AI013-3_flat.csv'

# %%
# Fahrzeuge in das DataFrame laden
file_path = os.path.join(root_raw, data_veh)
df_veh = pd.read_csv(file_path, sep=";", decimal=',' )
df_veh.head()
# Out:
#    statistics_code                                   statistics_label  \
# 0            46251  Statistik des Kraftfahrzeug- und Anhängerbesta...
# 1            46251  Statistik des Kraftfahrzeug- und Anhängerbesta...
# 2            46251  Statistik des Kraftfahrzeug- und Anhängerbesta...
# 3            46251  Statistik des Kraftfahrzeug- und Anhängerbesta...
# 4            46251  Statistik des Kraftfahrzeug- und Anhängerbesta...
#
#   time_code time_label        time 1_variable_code 1_variable_label  \
# 0      STAG   Stichtag  2020-01-01          KREISE           Kreise
# 1      STAG   Stichtag  2020-01-01          KREISE           Kreise
# 2      STAG   Stichtag  2020-01-01          KREISE           Kreise
# 3      STAG   Stichtag  2020-01-01          KREISE           Kreise
# 4      STAG   Stichtag  2020-01-01          KREISE           Kreise
#
#    1_variable_attribute_code      1_variable_attribute_label 2_variable_code  \
# ...

# %%
df_veh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38080 entries, 0 to 38079
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   statistics_code             38080 non-null  int64
#  1   statistics_label            38080 non-null  object
#  2   time_code                   38080 non-null  object
#  3   time_label                  38080 non-null  object
#  4   time                        38080 non-null  object
#  5   1_variable_code             38080 non-null  object
#  6   1_variable_label            38080 non-null  object
#  7   1_variable_attribute_code   38080 non-null  int64
#  8   1_variable_attribute_label  38080 non-null  object
#  9   2_variable_code             38080 non-null  object
#  10  2_variable_label            38080 non-null  object
#  11  2_variable_attribute_code   33320 non-null  object
#  12  2_variable_attribute_label  38080 non-null  object
# ...

# %%
# Die Anzahl der Fahrzeuge (Spalte value) in Typ int wandeln
df_veh['value'] = pd.to_numeric(df_veh['value'], errors='coerce').fillna(0).astype(int)
# Pivotieren nach Kraftstoff und Emissionsgruppe
df_pivot = df_veh.pivot_table(
    index='1_variable_attribute_code', 
    columns=['2_variable_attribute_label', '3_variable_attribute_label'], 
    values='value', 
    fill_value=0  # Falls es Landkreise gibt, die keine Einträge für bestimmte Kombinationen haben
)

# Um die Spaltennamen zu vereinfachen (z.B. Benzin_Euro5)
df_pivot.columns = [f"{fuel}_{emission}" for fuel, emission in df_pivot.columns]

df_pivot.tail()
# Out:
#                            Benzin_Euro 1  Benzin_Euro 2  Benzin_Euro 3  \
# 1_variable_attribute_code
# 16073                              441.0         2337.0         2245.0
# 16074                              383.0         1888.0         1970.0
# 16075                              383.0         1962.0         1938.0
# 16076                              473.0         2296.0         2271.0
# 16077                              469.0         2300.0         2338.0
#
#                            Benzin_Euro 4  Benzin_Euro 5  \
# 1_variable_attribute_code
# 16073                            12637.0        10535.0
# 16074                            10647.0         8168.0
# 16075                            10702.0         8462.0
# 16076                            13023.0        10153.0
# 16077                            12370.0         8991.0
#
#                            Benzin_Euro 6 (ohne 6d und 6d-temp)  \
# 1_variable_attribute_code
# ...

# %%
df_veh = df_veh.drop_duplicates(subset=['1_variable_attribute_code'])
df_veh = df_veh[['1_variable_attribute_code', '1_variable_attribute_label']].set_index('1_variable_attribute_code')
df_veh = df_veh.join(df_pivot, how='left')
df_veh
# Out:
#                                1_variable_attribute_label  Benzin_Euro 1  \
# 1_variable_attribute_code
# 9273                                   Kelheim, Landkreis          630.0
# 7231                       Bernkastel-Wittlich, Landkreis          675.0
# 12063                                Havelland, Landkreis          967.0
# 6438                                 Offenbach, Landkreis         2710.0
# 14523                                       Vogtlandkreis         1191.0
# ...                                                   ...            ...
# 3357                         Rotenburg (Wümme), Landkreis          875.0
# 6532                                      Lahn-Dill-Kreis         1602.0
# 6533                          Limburg-Weilburg, Landkreis         1053.0
# 3358                                           Heidekreis          869.0
# 5374                                 Oberbergischer Kreis         1684.0
#
# ...

# %%
# Bevölkerungszahlen in das DataFrame laden
file_path = os.path.join(root_raw, data_pop)
df_pop = pd.read_csv(file_path, sep=";", decimal=',', encoding='ISO-8859-1')
df_pop.head()
# Out:
#    Statistik_Code                Statistik_Label Zeit_Code Zeit_Label  Zeit  \
# 0           12211  Grundprogramm des Mikrozensus      JAHR       Jahr  2019
# 1           12211  Grundprogramm des Mikrozensus      JAHR       Jahr  2019
# 2           12211  Grundprogramm des Mikrozensus      JAHR       Jahr  2019
# 3           12211  Grundprogramm des Mikrozensus      JAHR       Jahr  2019
# 4           12211  Grundprogramm des Mikrozensus      JAHR       Jahr  2019
#
#   1_Merkmal_Code               1_Merkmal_Label 1_Auspraegung_Code  \
# 0         KREISE  Kreise und kreisfreie Städte                 DG
# 1         KREISE  Kreise und kreisfreie Städte                 DG
# 2         KREISE  Kreise und kreisfreie Städte                 DG
# 3         KREISE  Kreise und kreisfreie Städte                 DG
# 4         KREISE  Kreise und kreisfreie Städte                 DG
#
#   1_Auspraegung_Label 2_Merkmal_Code  \
# 0         Deutschland        ALTGR01
# ...

# %%
df_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8070 entries, 0 to 8069
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Statistik_Code                               8070 non-null   int64
#  1   Statistik_Label                              8070 non-null   object
#  2   Zeit_Code                                    8070 non-null   object
#  3   Zeit_Label                                   8070 non-null   object
#  4   Zeit                                         8070 non-null   int64
#  5   1_Merkmal_Code                               8070 non-null   object
#  6   1_Merkmal_Label                              8070 non-null   object
#  7   1_Auspraegung_Code                           8070 non-null   object
#  8   1_Auspraegung_Label                          8070 non-null   object
# ...

# %%
# Die Werte aus der Spalte 1_Auspraegung_Code in Typ int wandeln und Zeilen mit nicht numerischen Werten entfernen
df_pop['1_Auspraegung_Code'] = pd.to_numeric(df_pop['1_Auspraegung_Code'], errors='coerce')
df_pop.dropna(subset=['1_Auspraegung_Code'])
# Die Personenanzahl (Spalte BEVMZ11__Bevoelkerung_am_Hauptwohnort__1000) in Typ int wandeln
df_pop['BEVMZ11__Bevoelkerung_am_Hauptwohnort__1000'] = pd.to_numeric(df_pop['BEVMZ11__Bevoelkerung_am_Hauptwohnort__1000'], errors='coerce').fillna(0).astype(int)
# Pivotieren nach Geschlecht und Altersgruppe
df_pivot = df_pop.pivot_table(
    index='1_Auspraegung_Code', 
    columns=['3_Auspraegung_Label', '2_Auspraegung_Label'], 
    values='BEVMZ11__Bevoelkerung_am_Hauptwohnort__1000', 
    fill_value=0  # Falls es Landkreise gibt, die keine Einträge für bestimmte Kombinationen haben
)

# Um die Spaltennamen zu vereinfachen (z.B. männlich_unter 25 Jahre)
df_pivot.columns = [f"{gender}_{age}" for gender, age in df_pivot.columns]

df_pivot.tail()
# Out:
#                     Insgesamt_25 bis unter 45 Jahre  \
# 1_Auspraegung_Code
# 11008008.0                                    105.0
# 11009009.0                                     81.0
# 11010010.0                                     69.0
# 11011011.0                                     94.0
# 11012012.0                                     63.0
#
#                     Insgesamt_45 bis unter 65 Jahre  \
# 1_Auspraegung_Code
# 11008008.0                                     79.0
# 11009009.0                                     73.0
# 11010010.0                                     76.0
# 11011011.0                                     71.0
# 11012012.0                                     67.0
#
#                     Insgesamt_65 Jahre und mehr  Insgesamt_Insgesamt  \
# 1_Auspraegung_Code
# 11008008.0                                 59.0                318.0
# 11009009.0                                 48.0                265.0
# ...

# %%
df_pop = df_pop.drop_duplicates(subset=['1_Auspraegung_Code'])
df_pop = df_pop[['1_Auspraegung_Code', '1_Auspraegung_Label']].set_index('1_Auspraegung_Code')
df_pop= df_pop.join(df_pivot, how='left')
df_pop
# Out:
#                                            1_Auspraegung_Label  \
# 1_Auspraegung_Code
# NaN                                                Deutschland
# 1.0                                         Schleswig-Holstein
# 1001.0                             Flensburg, kreisfreie Stadt
# 1002.0                                  Kiel, kreisfreie Stadt
# 1003.0                    Lübeck, kreisfreie Stadt, Hansestadt
# ...                                                        ...
# 16073.0                         Saalfeld-Rudolstadt, Landkreis
# 16074.0                                   Saale-Holzland-Kreis
# 16075.0                                       Saale-Orla-Kreis
# 16076.0                                       Greiz, Landkreis
# 16077.0                            Altenburger Land, Landkreis
#
#                     Insgesamt_25 bis unter 45 Jahre  \
# 1_Auspraegung_Code
# NaN                                             NaN
# 1.0                                           663.0
# ...

# %%
# Entfernen der Zeilen aus df_pop, deren Indizes nicht in df_veh vorhanden sind
df_pop = df_pop[df_pop.index.isin(df_veh.index)]
df_pop
# Out:
#                                            1_Auspraegung_Label  \
# 1_Auspraegung_Code
# 1001.0                             Flensburg, kreisfreie Stadt
# 1002.0                                  Kiel, kreisfreie Stadt
# 1003.0                    Lübeck, kreisfreie Stadt, Hansestadt
# 1004.0                            Neumünster, kreisfreie Stadt
# 1051.0                                     Dithmarschen, Kreis
# ...                                                        ...
# 16073.0                         Saalfeld-Rudolstadt, Landkreis
# 16074.0                                   Saale-Holzland-Kreis
# 16075.0                                       Saale-Orla-Kreis
# 16076.0                                       Greiz, Landkreis
# 16077.0                            Altenburger Land, Landkreis
#
#                     Insgesamt_25 bis unter 45 Jahre  \
# 1_Auspraegung_Code
# 1001.0                                         26.0
# 1002.0                                         74.0
# ...

# %% [markdown]
# Anhand der Dimensionen kann man erkennen, dass es nicht zu jedem Landkreis aus den Zulassungsdaten Einwohnerzahlen gibt. Dennoch sollen sie wie folgt zusammengefügt werden:

# %%
# Entfernen von Überlappenden Spalten (alternativ umbenennen)
df_pop = df_pop.drop(columns=['1_Auspraegung_Label','Insgesamt_Insgesamt'])
df_veh = df_veh.drop(columns=['Insgesamt_Insgesamt'])
# Zusammenführen der DataFrames basierend auf dem Index
df_veh = df_veh.join(df_pop, how='inner')
df_veh
# Out:
#              1_variable_attribute_label  Benzin_Euro 1  Benzin_Euro 2  \
# 9273.0               Kelheim, Landkreis          630.0         3036.0
# 7231.0   Bernkastel-Wittlich, Landkreis          675.0         3174.0
# 12063.0            Havelland, Landkreis          967.0         4848.0
# 6438.0             Offenbach, Landkreis         2710.0        10856.0
# 14523.0                   Vogtlandkreis         1191.0         5521.0
# ...                                 ...            ...            ...
# 3357.0     Rotenburg (Wümme), Landkreis          875.0         5625.0
# 6532.0                  Lahn-Dill-Kreis         1602.0         7621.0
# 6533.0      Limburg-Weilburg, Landkreis         1053.0         5211.0
# 3358.0                       Heidekreis          869.0         4787.0
# 5374.0             Oberbergischer Kreis         1684.0         7849.0
#
#          Benzin_Euro 3  Benzin_Euro 4  Benzin_Euro 5  \
# 9273.0          2472.0        14582.0        10578.0
# ...

# %% [markdown]
# Analog wird mit den Datensätzen der Einkommen und der Unfallstatistik umgegangen. Diese werden ebenfalls dem DataFrame `df_veh` hinzugefügt. Die Datensätze sehen wie folgt aus:

# %%
# Einkommen in das DataFrame laden
file_path = os.path.join(root_raw, data_income)
df_income = pd.read_csv(file_path, sep=";", decimal=',', encoding='ISO-8859-1')
df_income.head()
# Out:
#    Statistik_Code            Statistik_Label Zeit_Code Zeit_Label  Zeit  \
# 0           99910  Regionalatlas Deutschland      JAHR       Jahr  2019
# 1           99910  Regionalatlas Deutschland      JAHR       Jahr  2019
# 2           99910  Regionalatlas Deutschland      JAHR       Jahr  2019
# 3           99910  Regionalatlas Deutschland      JAHR       Jahr  2019
# 4           99910  Regionalatlas Deutschland      JAHR       Jahr  2019
#
#   1_Merkmal_Code               1_Merkmal_Label 1_Auspraegung_Code  \
# 0         KREISE  Kreise und kreisfreie Städte                 DG
# 1         KREISE  Kreise und kreisfreie Städte                 01
# 2         KREISE  Kreise und kreisfreie Städte              01001
# 3         KREISE  Kreise und kreisfreie Städte              01002
# 4         KREISE  Kreise und kreisfreie Städte              01003
#
#                           1_Auspraegung_Label  \
# 0                                 Deutschland
# ...

# %%
# Unfallstatistik in das DataFrame laden
file_path = os.path.join(root_raw, data_crash)
df_crash = pd.read_csv(file_path, sep=";", decimal=',', encoding='ISO-8859-1')
df_crash.head()
# Out:
#    Statistik_Code            Statistik_Label Zeit_Code Zeit_Label  Zeit  \
# 0           99910  Regionalatlas Deutschland      JAHR       Jahr  2023
# 1           99910  Regionalatlas Deutschland      JAHR       Jahr  2023
# 2           99910  Regionalatlas Deutschland      JAHR       Jahr  2023
# 3           99910  Regionalatlas Deutschland      JAHR       Jahr  2023
# 4           99910  Regionalatlas Deutschland      JAHR       Jahr  2023
#
#   1_Merkmal_Code               1_Merkmal_Label 1_Auspraegung_Code  \
# 0         KREISE  Kreise und kreisfreie Städte                 DG
# 1         KREISE  Kreise und kreisfreie Städte                 01
# 2         KREISE  Kreise und kreisfreie Städte              01001
# 3         KREISE  Kreise und kreisfreie Städte              01002
# 4         KREISE  Kreise und kreisfreie Städte              01003
#
#                           1_Auspraegung_Label  \
# 0                                 Deutschland
# ...

# %% [markdown]
# ## Klassifikation
#
# ### Datenquellen
#
# siehe oben
#
# ### Forschungsfragen
#
# - Wie beeinflussen sozioökonomische Faktoren die Anzahl der zugelassenen Fahrzeuge in einem Landkreis?
#    - Antwortwert: Einteilung der Landkreise in "hohe" vs. "niedrige" Fahrzeugdichte-Kategorien.
#    - Merkmalswerte: Einkommen, Einwohneranzahl, Altersstruktur, Geschlechterverteilung
# - Inwiefern beeinflussen demografische und wirtschaftliche Faktoren die Kraftstoffart & Emissionsgruppen von Fahrzeugen in verschiedenen Landkreisen?
#    - Antwortwert: Einteilung der Landkreise in Kategorien wie "hoher Anteil moderner Fahrzeuge" vs. "hoher Anteil alter Emissionsgruppen".
#    - Merkmalswerte: Einkommen, Altersstruktur, Geschlechterverteilung
# - Welche Faktoren tragen zur Häufigkeit von Straßenverkehrsunfällen in Landkreisen bei?
#    - Antwortwert: Einteilung der Landkreise in "hohes Unfallrisiko" vs. "niedriges Unfallrisiko" auf Basis der Prädiktoren.
#    - Merkmalswerte: Anzahl der Fahrzeuge, Einkommen, Einwohneranzahl, Altersstruktur, Geschlechterverteilung
#
# ### Überblick über die Daten
#
# siehe oben
