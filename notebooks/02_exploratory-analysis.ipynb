# %% [markdown]
# # Datenanalyse und Exploration
#
# ---
#
# Autor: mn086
#
# ---

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
#import numpy as np

# %% [markdown]
# ## Daten-Import

# %% [markdown]
# **Pfade:**

# %%
root_processed = os.path.join('..', 'data', 'processed')

data = 'kfz_kombiniert.csv' # aufbereiteter Datensatz

# %% [markdown]
# **Import in Dataframes**

# %%
df_data = pd.read_csv(os.path.join(root_processed, data), index_col=0) # Dataframe Fahrzeugbestand

# %% [markdown]
# ## Daten-Struktur

# %%
df_data.tail(3)
# Out:
#      landkreis_id               landkreis  benzin_euro1  benzin_euro2  \
# 396          9778  Unterallgäu, Landkreis           971          4362
# 397          9779   Donau-Ries, Landkreis           853          4334
# 398          9780   Oberallgäu, Landkreis           914          3252
#
#      benzin_euro3  benzin_euro4  benzin_euro5  benzin_euro6  benzin_euro6d  \
# 396          3534         20334         14385         13035             30
# 397          3530         18599         12914         11386             43
# 398          2994         18687         15545         15712             74
#
#      benzin_euro6dt  ...  euro3  euro4  euro5  euro6  euro6d  euro6dt  \
# 396            2889  ...   6861  27297  27984  22648      64     4779
# 397            2865  ...   6993  25214  25475  20332     144     4954
# 398            4123  ...   6441  24325  29009  26362     148     6344
#
#      sonstigeemissionsgruppen    vee  anzahl_personen  unfaelle_je_10k_kfz
# 396                      2064  25966              NaN                 50.5
# 397                      1671  26021              NaN                 51.7
# 398                      2438  25954              NaN                 63.3
#
# [3 rows x 82 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399 entries, 0 to 398
# Data columns (total 82 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   landkreis_id                               399 non-null    int64
#  1   landkreis                                  399 non-null    object
#  2   benzin_euro1                               399 non-null    int64
#  3   benzin_euro2                               399 non-null    int64
#  4   benzin_euro3                               399 non-null    int64
#  5   benzin_euro4                               399 non-null    int64
#  6   benzin_euro5                               399 non-null    int64
#  7   benzin_euro6                               399 non-null    int64
#  8   benzin_euro6d                              399 non-null    int64
#  9   benzin_euro6dt                             399 non-null    int64
#  10  benzin_sonstigeemissionsgruppen            399 non-null    int64
#  11  diesel_euro1                               399 non-null    int64
#  12  diesel_euro2                               399 non-null    int64
#  13  diesel_euro3                               399 non-null    int64
#  14  diesel_euro4                               399 non-null    int64
#  15  diesel_euro5                               399 non-null    int64
#  16  diesel_euro6                               399 non-null    int64
#  17  diesel_euro6d                              399 non-null    int64
#  18  diesel_euro6dt                             399 non-null    int64
#  19  diesel_sonstigeemissionsgruppen            399 non-null    int64
#  20  elektro_euro1                              399 non-null    int64
#  21  elektro_euro2                              399 non-null    int64
#  22  elektro_euro3                              399 non-null    int64
#  23  elektro_euro4                              399 non-null    int64
#  24  elektro_euro5                              399 non-null    int64
#  25  elektro_euro6                              399 non-null    int64
#  26  elektro_euro6dt                            399 non-null    int64
#  27  elektro_sonstigeemissionsgruppen           399 non-null    int64
#  28  gas_euro1                                  399 non-null    int64
#  29  gas_euro2                                  399 non-null    int64
#  30  gas_euro3                                  399 non-null    int64
#  31  gas_euro4                                  399 non-null    int64
#  32  gas_euro5                                  399 non-null    int64
#  33  gas_euro6                                  399 non-null    int64
#  34  gas_euro6d                                 399 non-null    int64
#  35  gas_euro6dt                                399 non-null    int64
#  36  gas_sonstigeemissionsgruppen               399 non-null    int64
#  37  hybrid_euro1                               399 non-null    int64
#  38  hybrid_euro2                               399 non-null    int64
#  39  hybrid_euro3                               399 non-null    int64
#  40  hybrid_euro4                               399 non-null    int64
#  41  hybrid_euro5                               399 non-null    int64
#  42  hybrid_euro6                               399 non-null    int64
#  43  hybrid_euro6d                              399 non-null    int64
#  44  hybrid_euro6dt                             399 non-null    int64
#  45  hybrid_sonstigeemissionsgruppen            399 non-null    int64
#  46  pih_euro2                                  399 non-null    int64
#  47  pih_euro3                                  399 non-null    int64
#  48  pih_euro4                                  399 non-null    int64
#  49  pih_euro5                                  399 non-null    int64
#  50  pih_euro6                                  399 non-null    int64
#  51  pih_euro6d                                 399 non-null    int64
#  52  pih_euro6dt                                399 non-null    int64
#  53  pih_sonstigeemissionsgruppen               399 non-null    int64
#  54  sonstigeantriebe_euro1                     399 non-null    int64
#  55  sonstigeantriebe_euro2                     399 non-null    int64
#  56  sonstigeantriebe_euro3                     399 non-null    int64
#  57  sonstigeantriebe_euro4                     399 non-null    int64
#  58  sonstigeantriebe_euro5                     399 non-null    int64
#  59  sonstigeantriebe_euro6                     399 non-null    int64
#  60  sonstigeantriebe_euro6dt                   399 non-null    int64
#  61  sonstigeantriebe_sonstigeemissionsgruppen  399 non-null    int64
#  62  anzahl_kfz                                 399 non-null    int64
#  63  benzin                                     399 non-null    int64
#  64  diesel                                     399 non-null    int64
#  65  elektro                                    399 non-null    int64
#  66  gas                                        399 non-null    int64
#  67  hybrid                                     399 non-null    int64
#  68  pih                                        399 non-null    int64
#  69  sonstigeantriebe                           399 non-null    int64
#  70  euro1                                      399 non-null    int64
#  71  euro2                                      399 non-null    int64
#  72  euro3                                      399 non-null    int64
#  73  euro4                                      399 non-null    int64
#  74  euro5                                      399 non-null    int64
#  75  euro6                                      399 non-null    int64
#  76  euro6d                                     399 non-null    int64
#  77  euro6dt                                    399 non-null    int64
#  78  sonstigeemissionsgruppen                   399 non-null    int64
#  79  vee                                        399 non-null    int64
#  80  anzahl_personen                            216 non-null    float64
#  81  unfaelle_je_10k_kfz                        399 non-null    float64
# dtypes: float64(2), int64(79), object(1)
# memory usage: 258.7+ KB

# %% [markdown]
# ## Variablen Listen

# %%
list_meta = ['landkreis_id', 'landkreis']  # Meta-Informationen zu den Landkreisen
list_num = [col for col in df_data.columns if col not in list_meta and pd.api.types.is_numeric_dtype(df_data[col])] # Liste numerischer Spalten
list_kfz_aggr = [
    "benzin", "diesel", "elektro", "gas", "hybrid", "pih", "sonstigeantriebe",
    "euro1", "euro2", "euro3", "euro4", "euro5", "euro6", "euro6dt", "euro6d", "sonstigeemissionsgruppen"] # Aggregierte Spalten
list_kfz_aggr_antriebe = ["benzin", "diesel", "elektro", "gas", "hybrid", "pih", "sonstigeantriebe"] # Aggregierte Antriebe
list_kfz_aggr_eg = [col for col in list_kfz_aggr if col not in list_kfz_aggr_antriebe] # Aggregierte Emissionsgruppen
list_kfz_num = [col for col in list_num if col not in list_kfz_aggr and col not in
                ['gesamt', 'vee', 'anzahl_personen', 'unfaelle_je_10k_kfz']] # Nicht aggregierte Spalten (Kombination Antrieb & Emissionsgruppe)

# %%
# Dataframe der aggregierten Antriebe
df_antriebe = df_data[['landkreis'] + list_kfz_aggr_antriebe]
# Normierten DataFrame in Prozent erstellen
df_antriebe_prozent = df_antriebe.copy()
df_antriebe_prozent[list_kfz_aggr_antriebe] = df_antriebe[list_kfz_aggr_antriebe].apply(lambda x: x / x.sum() * 100, axis=1)

# Dataframe der aggregierten Emissionsgruppen
df_eg = df_data[['landkreis'] + list_kfz_aggr_eg]
# Normierten DataFrame in Prozent erstellen
df_eg_prozent = df_eg.copy()
df_eg_prozent[list_kfz_aggr_eg] = df_eg[list_kfz_aggr_eg].apply(lambda x: x / x.sum() * 100, axis=1)

# Dataframe für die Korrelation erstellen
df_corr = pd.DataFrame(pd.concat([df_data[['anzahl_personen', 'vee', 'anzahl_kfz', 'unfaelle_je_10k_kfz']],
                                  df_antriebe_prozent[list_kfz_aggr_antriebe],
                                  df_eg_prozent[list_kfz_aggr_eg]], axis=1))

# %%
import altair as alt

def create_stacked_bar_chart(df, id_vars, var_name, value_name, x_axis_title, chart_title):
    """
    Erstellt ein gestapeltes Balkendiagramm aus einem DataFrame.

    Parameter:
    df (pd.DataFrame): Der DataFrame, der die Daten enthält
    id_vars (list): Liste der Spalten, die als Identifikatoren verwendet werden
    var_name (str): Name der Spalte, die die Kategorien enthält
    value_name (str): Name der Spalte, die die Werte enthält
    x_axis_title (str): Titel der x-Achse
    chart_title (str): Titel des Diagramms

    Rückgabewert:
    alt.Chart: Das erstellte gestapelte Balkendiagramm
    """
    
    # Den DataFrame schmelzen, um Motortypen in eine einzelne Spalte zu konvertieren
    df_melted = df.melt(
        id_vars=id_vars, 
        var_name=var_name, 
        value_name=value_name
    )

    # Gestapeltes Balkendiagramm erstellen
    chart = alt.Chart(df_melted).mark_bar().encode(
        x=alt.X(f'{id_vars[0]}:N', axis=alt.Axis(labels=False, title=x_axis_title)),  # Labels aufgrund der großen Anzahl ausblenden
        y=alt.Y(f'{value_name}:Q', stack='zero'),
        color=f'{var_name}:N',
        tooltip=[id_vars[0], var_name, value_name]
    ).properties(
        width=800,
        height=400,
        title=chart_title
    )
    
    return chart

# %%
# Beispielaufruf für df_antriebe
chart_antriebe = create_stacked_bar_chart(
    df=df_antriebe,
    id_vars=['landkreis'],
    var_name='antriebsart',
    value_name='Anzahl',
    x_axis_title='Landkreis',
    chart_title='Fahrzeugbestand nach Antriebsart und Landkreis'
)
chart_antriebe
# Out:
# alt.Chart(...)

# %%
# Beispielaufruf für df_eg
chart_eg = create_stacked_bar_chart(
    df=df_eg,
    id_vars=['landkreis'],
    var_name='Emissiongruppe',
    value_name='Anzahl',
    x_axis_title='Landkreis',
    chart_title='Fahrzeugbestand nach Emissionsgruppe und Landkreis'
)
chart_eg
# Out:
# alt.Chart(...)

# %%
# Beispielaufruf für df_antriebe (normiert)
chart_antriebe_prozent = create_stacked_bar_chart(
    df=df_antriebe_prozent,
    id_vars=['landkreis'],
    var_name='antriebsart',
    value_name='Anteil',
    x_axis_title='Landkreis',
    chart_title='Fahrzeugbestand nach Antriebsart und Landkreis'
)
chart_antriebe_prozent
# Out:
# alt.Chart(...)

# %%
# Beispielaufruf für df_eg (normiert)
chart_eg_prozent = create_stacked_bar_chart(
    df=df_eg_prozent,
    id_vars=['landkreis'],
    var_name='Emissiongruppe',
    value_name='Anteil',
    x_axis_title='Landkreis',
    chart_title='Fahrzeugbestand nach Emissionsgruppe und Landkreis'
)
chart_eg_prozent
# Out:
# alt.Chart(...)

# %%
corr_pearson = df_corr.corr()
corr_pearson.style.background_gradient(cmap='Blues', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_05e64_row0_col0, #T_05e64_row1_col1, #T_05e64_row2_col2, #T_05e64_row3_col3, #T_05e64_row4_col4, #T_05e64_row5_col5, #T_05e64_row6_col6, #T_05e64_row7_col7, #T_05e64_row8_col8, #T_05e64_row9_col9, #T_05e64_row10_col10, #T_05e64_row11_col11, #T_05e64_row12_col12, #T_05e64_row13_col13, #T_05e64_row14_col14, #T_05e64_row15_col15, #T_05e64_row16_col16, #T_05e64_row17_col17, #T_05e64_row18_col18, #T_05e64_row19_col19 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col1, #T_05e64_row0_col7, #T_05e64_row1_col0, #T_05e64_row2_col16, #T_05e64_row7_col0, #T_05e64_row16_col2, #T_05e64_row16_col19, #T_05e64_row19_col16 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col2, #T_05e64_row2_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col3, #T_05e64_row3_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col4, #T_05e64_row0_col18, #T_05e64_row4_col0, #T_05e64_row4_col8, #T_05e64_row5_col6, #T_05e64_row6_col5, #T_05e64_row8_col4, #T_05e64_row18_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col5, #T_05e64_row4_col19, #T_05e64_row5_col0, #T_05e64_row5_col14, #T_05e64_row7_col17, #T_05e64_row10_col17, #T_05e64_row14_col5, #T_05e64_row17_col7, #T_05e64_row17_col10, #T_05e64_row19_col4 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_05e64_row0_col6, #T_05e64_row5_col9, #T_05e64_row6_col0, #T_05e64_row6_col11, #T_05e64_row9_col5, #T_05e64_row11_col6 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col8, #T_05e64_row8_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col9, #T_05e64_row3_col8, #T_05e64_row6_col17, #T_05e64_row8_col3, #T_05e64_row9_col0, #T_05e64_row17_col6 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col10, #T_05e64_row5_col18, #T_05e64_row7_col8, #T_05e64_row8_col7, #T_05e64_row10_col0, #T_05e64_row18_col5 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_05e64_row0_col11, #T_05e64_row2_col17, #T_05e64_row9_col11, #T_05e64_row11_col0, #T_05e64_row11_col9, #T_05e64_row17_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col12, #T_05e64_row3_col10, #T_05e64_row10_col3, #T_05e64_row12_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col13, #T_05e64_row5_col17, #T_05e64_row13_col0, #T_05e64_row17_col5 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col14, #T_05e64_row7_col9, #T_05e64_row9_col7, #T_05e64_row14_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_05e64_row0_col15, #T_05e64_row15_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_05e64_row0_col16, #T_05e64_row8_col11, #T_05e64_row11_col8, #T_05e64_row16_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_05e64_row0_col17, #T_05e64_row0_col19, #T_05e64_row2_col4, #T_05e64_row3_col17, #T_05e64_row4_col2, #T_05e64_row17_col0, #T_05e64_row17_col3, #T_05e64_row19_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col2, #T_05e64_row1_col18, #T_05e64_row2_col1, #T_05e64_row10_col15, #T_05e64_row15_col10, #T_05e64_row18_col1, #T_05e64_row18_col19, #T_05e64_row19_col18 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col3, #T_05e64_row3_col1, #T_05e64_row10_col19, #T_05e64_row12_col18, #T_05e64_row18_col12, #T_05e64_row19_col10 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_05e64_row1_col4, #T_05e64_row4_col1, #T_05e64_row11_col15, #T_05e64_row14_col19, #T_05e64_row15_col11, #T_05e64_row19_col14 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_05e64_row1_col5, #T_05e64_row5_col1, #T_05e64_row9_col16, #T_05e64_row16_col9 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col6, #T_05e64_row1_col11, #T_05e64_row6_col1, #T_05e64_row11_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col7, #T_05e64_row7_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_05e64_row1_col8, #T_05e64_row2_col7, #T_05e64_row6_col18, #T_05e64_row7_col2, #T_05e64_row8_col1, #T_05e64_row18_col6 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col9, #T_05e64_row9_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col10, #T_05e64_row2_col15, #T_05e64_row10_col1, #T_05e64_row15_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_05e64_row1_col12, #T_05e64_row12_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_05e64_row1_col13, #T_05e64_row13_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_05e64_row1_col14, #T_05e64_row14_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_05e64_row1_col15, #T_05e64_row5_col13, #T_05e64_row10_col18, #T_05e64_row13_col5, #T_05e64_row15_col1, #T_05e64_row18_col10 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_05e64_row1_col16, #T_05e64_row16_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col17, #T_05e64_row17_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_05e64_row1_col19, #T_05e64_row19_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col3, #T_05e64_row3_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col5, #T_05e64_row4_col6, #T_05e64_row5_col2, #T_05e64_row6_col4, #T_05e64_row6_col12, #T_05e64_row12_col6 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_05e64_row2_col6, #T_05e64_row6_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col8, #T_05e64_row8_col2 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col9, #T_05e64_row9_col2 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col10, #T_05e64_row10_col2 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_05e64_row2_col11, #T_05e64_row11_col2, #T_05e64_row16_col17, #T_05e64_row17_col16 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col12, #T_05e64_row7_col19, #T_05e64_row8_col10, #T_05e64_row10_col8, #T_05e64_row11_col18, #T_05e64_row12_col2, #T_05e64_row18_col11, #T_05e64_row19_col7 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col13, #T_05e64_row10_col12, #T_05e64_row12_col10, #T_05e64_row13_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_05e64_row2_col14, #T_05e64_row5_col12, #T_05e64_row8_col12, #T_05e64_row10_col11, #T_05e64_row11_col10, #T_05e64_row12_col5, #T_05e64_row12_col8, #T_05e64_row14_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_05e64_row2_col18, #T_05e64_row3_col16, #T_05e64_row4_col12, #T_05e64_row10_col14, #T_05e64_row12_col4, #T_05e64_row14_col10, #T_05e64_row16_col3, #T_05e64_row18_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_05e64_row2_col19, #T_05e64_row3_col11, #T_05e64_row4_col14, #T_05e64_row11_col3, #T_05e64_row14_col4, #T_05e64_row19_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_05e64_row3_col4, #T_05e64_row3_col6, #T_05e64_row3_col13, #T_05e64_row3_col19, #T_05e64_row4_col3, #T_05e64_row6_col3, #T_05e64_row6_col16, #T_05e64_row13_col3, #T_05e64_row16_col6, #T_05e64_row19_col3 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_05e64_row3_col5, #T_05e64_row5_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_05e64_row3_col7, #T_05e64_row7_col3, #T_05e64_row7_col11, #T_05e64_row11_col7 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_05e64_row3_col9, #T_05e64_row9_col3 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_05e64_row3_col12, #T_05e64_row4_col13, #T_05e64_row12_col3, #T_05e64_row13_col4 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_05e64_row3_col14, #T_05e64_row14_col3 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_05e64_row3_col15, #T_05e64_row15_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_05e64_row3_col18, #T_05e64_row18_col3 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_05e64_row4_col5, #T_05e64_row5_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_05e64_row4_col7, #T_05e64_row7_col4, #T_05e64_row11_col14, #T_05e64_row14_col11 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_05e64_row4_col9, #T
